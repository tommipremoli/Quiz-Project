# %% [markdown]
# ## Data Import

# %%
import pandas as pd

# %%
movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# %%
movies
# Out:
#                                             movie_title    year  \
# 0                                                Avatar  2009.0
# 1              Pirates of the Caribbean: At World's End  2007.0
# 2                                               Spectre  2015.0
# 3                                 The Dark Knight Rises  2012.0
# 4     Star Wars: Episode VII - The Force Awakens    ...     NaN
# ...                                                 ...     ...
# 5038                            Signed Sealed Delivered  2013.0
# 5039                          The Following                 NaN
# 5040                               A Plague So Pleasant  2013.0
# 5041                                   Shanghai Calling  2012.0
# 5042                                  My Date with Drew  2004.0
#
#           director_name       actor_name                           genres  \
# 0         James Cameron      CCH Pounder  Action|Adventure|Fantasy|Sci-Fi
# 1        Gore Verbinski      Johnny Depp         Action|Adventure|Fantasy
# 2            Sam Mendes  Christoph Waltz        Action|Adventure|Thriller
# 3     Christopher Nolan        Tom Hardy                  Action|Thriller
# 4           Doug Walker      Doug Walker                      Documentary
# ...                 ...              ...                              ...
# 5038        Scott Smith      Eric Mabius                     Comedy|Drama
# 5039                NaN      Natalie Zea     Crime|Drama|Mystery|Thriller
# 5040   Benjamin Roberds      Eva Boehnke            Drama|Horror|Thriller
# 5041        Daniel Hsia        Alan Ruck             Comedy|Drama|Romance
# 5042           Jon Gunn      John August                      Documentary
#
#      country
# 0        USA
# 1        USA
# 2         UK
# 3        USA
# 4        NaN
# ...      ...
# 5038  Canada
# 5039     USA
# 5040     USA
# 5041     USA
# 5042     USA
#
# [5043 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

movies['genres'] = movies['genres'].str.lower()

def format_genres(genres):
 genres = genres.split('|')
 if len(genres) > 1:
     genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
 else:
     genres = genres[0]
 return genres

movies['genres'] = movies['genres'].apply(format_genres)

movies.dropna(inplace=True)

movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)

# %%
movies
# Out:
#                                    movie_title  year      director_name  \
# 0                                       Avatar  2009      James Cameron
# 1     Pirates of the Caribbean: At World's End  2007     Gore Verbinski
# 2                                      Spectre  2015         Sam Mendes
# 3                        The Dark Knight Rises  2012  Christopher Nolan
# 5                                  John Carter  2012     Andrew Stanton
# ...                                        ...   ...                ...
# 5037                                 Newlyweds  2011       Edward Burns
# 5038                   Signed Sealed Delivered  2013        Scott Smith
# 5040                      A Plague So Pleasant  2013   Benjamin Roberds
# 5041                          Shanghai Calling  2012        Daniel Hsia
# 5042                         My Date with Drew  2004           Jon Gunn
#
#            actor_name                                 genres country
# 0         CCH Pounder  action, adventure, fantasy and sci-fi     USA
# 1         Johnny Depp          action, adventure and fantasy     USA
# 2     Christoph Waltz         action, adventure and thriller      UK
# 3           Tom Hardy                    action and thriller     USA
# 5        Daryl Sabara           action, adventure and sci-fi     USA
# ...               ...                                    ...     ...
# 5037      Kerry Bishé                       comedy and drama     USA
# 5038      Eric Mabius                       comedy and drama  Canada
# 5040      Eva Boehnke             drama, horror and thriller     USA
# 5041        Alan Ruck              comedy, drama and romance     USA
# 5042      John August                            documentary     USA
#
# [4927 rows x 6 columns]

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.hist(movies.year)
plt.show()

# %% [markdown]
# ## Program Creation

# %%
import pandas as pd
from numpy import random
import string
import matplotlib.pyplot as plt
import time

ID = ['A', 'B', 'C', 'D']

# Data import
movies = pd.read_excel('Dataset/Movie_Dataset.xlsx')

# Data Cleaning
movies['genres'] = movies['genres'].str.lower()


def format_genres(genres):
    genres = genres.split('|')
    if len(genres) > 1:
        genres = ', '.join(genres[:-1]) + ' and ' + genres[-1]
    else:
        genres = genres[0]
    return genres


movies['genres'] = movies['genres'].apply(format_genres)
movies.dropna(inplace=True)
movies['year'] = pd.to_numeric(movies['year'], errors='coerce').fillna(0).astype(int)

# Start of quiz creation
# Function for choosing difficulty
def choose_difficulty():
    difficulty = input("Choose your difficulty level (Easy/Difficult): ").lower()
    if difficulty == 'easy':
        return movies['year'] > 1990, 5 * 60
    elif difficulty == 'difficult':
        return movies['year'] < 1990, 3 * 60
    else:
        print("Invalid choice, defaulting to Easy")
        return movies['year'] > 1990, 5 * 60 

# Function for random question generation
def generate_question(movies, difficulty_filter):
    correct_movie = movies[difficulty_filter].sample(1)
    question = f"What is the title of the film released in {correct_movie['year'].values[0]} directed by {correct_movie['director_name'].values[0]}, starring {correct_movie['actor_name'].values[0]}, produced in {correct_movie['country'].values[0]} and belonging to the genre {correct_movie['genres'].values[0]}?"
    return question, correct_movie

# Function for generating 3 wrong answers and 1 right answer
def generate_answers(movies, correct_movie):
    incorrect_movies = movies.drop(correct_movie.index.values.tolist())
    incorrect_answers = incorrect_movies.sample(3)['movie_title'].values
    correct_answer = correct_movie['movie_title'].values[0]
    answers = [correct_answer] + list(incorrect_answers)
    random.shuffle(answers)
    return answers
# Creation of the actual quiz in which difficulty and score are taken into account for the creation of the final graph
def quiz(movies):
    difficulty_filter, time_limit = choose_difficulty()
    start_time = time.time()
    score = 0
    score_history = [0]

    for i in range(1, 11):
        elapsed_time = time.time() - start_time
        remaining_time = max(0, time_limit - elapsed_time)
        print(f"\nTime remaining: {int(remaining_time // 60)} minutes {int(remaining_time % 60)} seconds\n")

        question, correct_movie = generate_question(movies, difficulty_filter)
        answers = generate_answers(movies, correct_movie)
        print(f"Question {i}. {question}")

        for j, answer in zip(ID, answers):
            print(f"{j}. {answer}")

        user_answer = input("Your answer: ").upper()
        while user_answer not in ID:
           print("You have another chance, try again!")
           user_answer = input("Your answer: ").upper()


        correct_answer = correct_movie['movie_title'].values[0]
        selected_answer = answers[string.ascii_uppercase.index(user_answer)]
        if selected_answer == correct_answer:
            print("Correct!\n")
            score += 1
            score_history.append(score)
        else:
            print(f"Wrong! The correct answer is {correct_answer}\n")
            score_history.append(score)

        elapsed_time = time.time() - start_time
        if elapsed_time > time_limit:
            print("Time's up!")
            break

    print(f"\nYour total score is {score}/10!\n")
    plt.plot(score_history)
    plt.xlabel('Question number')
    plt.ylabel('Score')
    plt.title('Score over time')
    plt.ylim(0, 10)
    plt.show()
    retry = input("Do you want to retry? (yes/no): ").lower()
    if retry != 'no':
        quiz(movies)
    else:
        print("\nThanks for trying!")

quiz(movies)
# Out:
# Choose your difficulty level (Easy/Difficult): easy
#
# Time remaining: 4 minutes 59 seconds
#
# Question 1. What is the title of the film released in 2010 directed by Ray Griggs, starring Bill Farmer, produced in USA and belonging to the genre documentary?
# A. The Hobbit: An Unexpected Journey
# B. Gossip
# C. I Want Your Money
# D. London to Brighton
# Your answer: a
# Wrong! The correct answer is I Want Your Money
#
#
# Time remaining: 4 minutes 26 seconds
#
# Question 2. What is the title of the film released in 2006 directed by Lloyd Kaufman, starring John Karyus, produced in USA and belonging to the genre comedy, horror and musical?
# A. The Lovely Bones
# B. Poultrygeist: Night of the Chicken Dead
# C. The Box
# D. Guiana 1838
# Your answer: b
# Correct!
#
#
# Time remaining: 4 minutes 25 seconds
#
# Question 3. What is the title of the film released in 2013 directed by Justin Chadwick, starring Terry Pheto, produced in UK and belonging to the genre biography, drama and history?
# A. The Maze Runner
# B. The Haunting in Connecticut 2: Ghosts of Georgia
# C. Mandela: Long Walk to Freedom
# D. A Man for All Seasons
# Your answer: d
# Wrong! The correct answer is Mandela: Long Walk to Freedom
#
#
# Time remaining: 4 minutes 24 seconds
#
# Question 4. What is the title of the film released in 2013 directed by Jonathan Newman, starring Ioan Gruffudd, produced in UK and belonging to the genre adventure, family and fantasy?
# A. The Haunting in Connecticut 2: Ghosts of Georgia
# B. The Adventurer: The Curse of the Midas Box
# C. Kiss Kiss Bang Bang
# D. Harvard Man
# Your answer: a
# Wrong! The correct answer is The Adventurer: The Curse of the Midas Box
#
#
# Time remaining: 4 minutes 23 seconds
#
# Question 5. What is the title of the film released in 2011 directed by Lee Tamahori, starring Mem Ferda, produced in Belgium and belonging to the genre biography, drama and thriller?
# A. The Devil's Double
# B. Sunshine Cleaning
# C. Skin Trade
# D. Pocahontas
# Your answer: j
# You have another chance, try again!
# Your answer: 6
# You have another chance, try again!
# Your answer: -
# You have another chance, try again!
# Your answer: a
# Correct!
#
#
# Time remaining: 4 minutes 1 seconds
#
# Question 6. What is the title of the film released in 2014 directed by Ben Falcone, starring Gary Cole, produced in USA and belonging to the genre comedy?
# A. Justin Bieber: Never Say Never
# B. Freeway
# C. Tammy
# D. Snow Dogs
# Your answer: a
# Wrong! The correct answer is Tammy
#
#
# Time remaining: 4 minutes 0 seconds
#
# Question 7. What is the title of the film released in 2015 directed by Shyam Madiraju, starring Jessica Lowndes, produced in Spain and belonging to the genre drama and thriller?
# A. Smokin' Aces
# B. Begin Again
# C. Eden
# D. History of the World: Part I
# Your answer: b
# Wrong! The correct answer is Eden
#
#
# Time remaining: 3 minutes 59 seconds
#
# Question 8. What is the title of the film released in 2003 directed by Sylvain Chomet, starring Michel Robin, produced in France and belonging to the genre animation, comedy and drama?
# A. 30 Minutes or Less
# B. Spider
# C. Girl, Interrupted
# D. The Triplets of Belleville
# Your answer: d
# Correct!
#
#
# Time remaining: 3 minutes 59 seconds
#
# Question 9. What is the title of the film released in 2012 directed by Harmony Korine, starring James Franco, produced in USA and belonging to the genre crime and drama?
# A. Brave New Girl
# B. The Hobbit: The Battle of the Five Armies
# C. Spring Breakers
# D. Extraordinary Measures
# Your answer: c
# Correct!
#
#
# Time remaining: 3 minutes 58 seconds
#
# Question 10. What is the title of the film released in 2010 directed by Denis Villeneuve, starring Lubna Azabal, produced in Canada and belonging to the genre drama, mystery and war?
# A. Edge of Darkness
# B. Blood and Wine
# C. Incendies
# D. Warlock: The Armageddon
# Your answer: d
# Wrong! The correct answer is Incendies
#
#
# Your total score is 4/10!
# Do you want to retry? (yes/no): no
#
# Thanks for trying!
